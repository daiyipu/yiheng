# %%
# 示例数据,仅支持数据已经是list-in-lists的形式
transactions = [
    ['面包', '牛奶', '鸡蛋'],
    ['面包', '牛奶', '麦片'],
    ['面包', '鸡蛋', '麦片'],
    ['牛奶', '鸡蛋', '麦片'],
    ['面包', '牛奶', '饼干'],
    ['牛奶', '饼干', '麦片'],
    ['面包', '鸡蛋', '饼干'],
    ['鸡蛋', '饼干', '麦片'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干'],
    ['面包', '牛奶', '鸡蛋', '饼干'],
    ['牛奶', '鸡蛋', '麦片', '饼干'],
    ['面包', '鸡蛋', '麦片', '饼干'],
    ['牛奶', '麦片', '饼干'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '牙膏'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '洗发水'],
    ['牛奶', '鸡蛋', '麦片', '饼干', '牙膏'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '洗发水', '巧克力'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水'],
    ['牛奶', '鸡蛋', '麦片', '饼干', '牙膏', '洗发水'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '牙膏', '洗发水'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水', '香皂'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水', '香皂', '洗衣粉'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水', '香皂', '洗衣粉', '洗洁精'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '牙膏', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片', '益生菌'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '牙膏', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片', '益生菌', '咖啡'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '牙膏', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片', '益生菌', '咖啡', '茶'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '牙膏', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片', '益生菌', '咖啡', '茶', '口香糖'],
    ['面包', '牛奶', '鸡蛋', '麦片', '饼干', '巧克力', '牙膏', '洗发水', '香皂', '洗衣粉', '洗洁精', '维生素', '钙片', '益生菌', '咖啡', '茶', '口香糖', '橄榄油'],
    # ... 更多交易
]

dataset=transactions

# %%
# 调包演示
import pyfpgrowth
patterns = pyfpgrowth.find_frequent_patterns(transactions, 10)  # 频数删选  频数大于2

# %%
patterns_specific={}
for i in patterns.keys():
    if '鸡蛋' in i:
        print(i)
        patterns_specific[i]=patterns[i]
        print(patterns_specific[i])
# Out:
# ('香皂', '鸡蛋')
# 10
# ('巧克力', '香皂', '鸡蛋')
# 10
# ('洗发水', '香皂', '鸡蛋')
# 10
# ('面包', '香皂', '鸡蛋')
# 10
# ('饼干', '香皂', '鸡蛋')
# 10
# ('香皂', '鸡蛋', '麦片')
# 10
# ('牛奶', '香皂', '鸡蛋')
# 10
# ('巧克力', '洗发水', '香皂', '鸡蛋')
# 10
# ('巧克力', '面包', '香皂', '鸡蛋')
# 10
# ('巧克力', '饼干', '香皂', '鸡蛋')
# 10
# ('巧克力', '香皂', '鸡蛋', '麦片')
# 10
# ('巧克力', '牛奶', '香皂', '鸡蛋')
# 10
# ('洗发水', '面包', '香皂', '鸡蛋')
# 10
# ('洗发水', '饼干', '香皂', '鸡蛋')
# 10
# ('洗发水', '香皂', '鸡蛋', '麦片')
# 10
# ('洗发水', '牛奶', '香皂', '鸡蛋')
# 10
# ('面包', '饼干', '香皂', '鸡蛋')
# 10
# ('面包', '香皂', '鸡蛋', '麦片')
# 10
# ('牛奶', '面包', '香皂', '鸡蛋')
# 10
# ('饼干', '香皂', '鸡蛋', '麦片')
# 10
# ('牛奶', '饼干', '香皂', '鸡蛋')
# 10
# ('牛奶', '香皂', '鸡蛋', '麦片')
# 10
# ('巧克力', '洗发水', '面包', '香皂', '鸡蛋')
# 10
# ('巧克力', '洗发水', '饼干', '香皂', '鸡蛋')
# 10
# ('巧克力', '洗发水', '香皂', '鸡蛋', '麦片')
# 10
# ('巧克力', '洗发水', '牛奶', '香皂', '鸡蛋')
# 10
# ('巧克力', '面包', '饼干', '香皂', '鸡蛋')
# 10
# ('巧克力', '面包', '香皂', '鸡蛋', '麦片')
# 10
# ('巧克力', '牛奶', '面包', '香皂', '鸡蛋')
# 10
# ('巧克力', '饼干', '香皂', '鸡蛋', '麦片')
# 10
# ...

# %%
rules = pyfpgrowth.generate_association_rules(patterns_specific,0.2)  # 置信度(条件概率)删选
len(rules)
# Out:
# 127

# %%
for i in rules.keys():
    if '香皂' in i and len(i)==1:
        print(rules[i])
