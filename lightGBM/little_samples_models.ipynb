# %%
import lightgbm as lgbm
import pandas as pd

# %%
red_win_date=pd.read_csv(r'wine+quality/winequality-red.csv',sep=';')
white_win_date=pd.read_csv(r'wine+quality/winequality-white.csv',sep=';')

# %%
feature=red_win_date.columns

# %%
red_win_date['target']=1
white_win_date['target']=0

# %%
win_date=pd.concat([red_win_date,white_win_date])

# %%
win_date.reset_index(drop=True,inplace=True)

# %%
import lightgbm as lgb
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.datasets import make_classification

# 1. 生成示例数据集
# X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)

# 2. 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(win_date[feature], win_date['target'], test_size=0.2, random_state=42)

# 3. 创建 LightGBM 数据集
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test, reference=train_data)

# 4. 设置模型参数
params = {
    'objective': 'binary',  # 二分类任务
    'metric': 'binary_logloss',  # 评估指标
    'boosting_type': 'gbdt',  # 梯度提升决策树
    'num_leaves': 31,  # 叶子节点数
    'learning_rate': 0.05,  # 学习率
    'feature_fraction': 0.9,  # 特征采样比例
    'bagging_fraction': 0.8,  # 数据采样比例
    'bagging_freq': 5,  # 每 5 次迭代进行一次 bagging
    'verbose': 0  # 不输出日志
}

# 5. 训练模型
model = lgb.train(
    params,
    train_data,
    num_boost_round=100,  # 迭代次数
    valid_sets=[test_data],  # 验证集
    callbacks=[lgb.early_stopping(stopping_rounds=10)]  # 早停法
)

# 6. 预测
y_pred = model.predict(X_test, num_iteration=model.best_iteration)  # 预测概率
y_pred_class = np.round(y_pred)  # 将概率转换为类别（0 或 1）

# 7. 评估模型
accuracy = accuracy_score(y_test, y_pred_class)
auc = roc_auc_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"AUC: {auc:.4f}")

# 8. 保存模型
model.save_model('lightgbm_model.txt')

# 9. 加载模型（可选）
# loaded_model = lgb.Booster(model_file='lightgbm_model.txt')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# Training until validation scores don't improve for 10 rounds
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.0261059
# Accuracy: 0.9946
# AUC: 0.9980

# %%
def _parse_tree(node, prefix):
    if 'split_index' in node:  # 非叶子节点
        feature = node['split_feature']
        threshold = node['threshold']
        print(f"{prefix} -> Split on feature {feature} (threshold: {threshold:.4f})")
        _parse_tree(node['left_child'], prefix + " -> Left")
        _parse_tree(node['right_child'], prefix + " -> Right")
    else:  # 叶子节点
        print(f"{prefix} -> Leaf (prediction: {node['leaf_value']:.4f})")

# 6. 获取单一样本的预测路径（可选）
def get_prediction_path(model, sample):
    pred_path = []
    for tree in trees:
        node = tree['tree_structure']
        while 'split_index' in node:
            feature = node['split_feature']
            threshold = node['threshold']
            if sample[feature] <= threshold:
                node = node['left_child']
                pred_path.append(f"Feature {feature} <= {threshold:.4f}")
            else:
                node = node['right_child']
                pred_path.append(f"Feature {feature} > {threshold:.4f}")
        pred_path.append(f"Leaf (prediction: {node['leaf_value']:.4f})")
    return pred_path

# %%
# 3. 获取模型的所有树
trees = model.dump_model()['tree_info']

# 4. 遍历每棵树，提取特征组合和预测值
for tree_id, tree in enumerate(trees):
    print(f"\nTree {tree_id + 1}:")
    tree_structure = tree['tree_structure']
    _parse_tree(tree_structure, prefix="Root")

# 5. 定义递归函数解析树结构

# 7. 测试单一样本的预测路径
# Out:
# Tree 1:
# Root -> Split on feature 6 (threshold: 65.5000)
# Root -> Left -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Left -> Split on feature 8 (threshold: 3.2350)
# Root -> Left -> Left -> Left -> Split on feature 0 (threshold: 7.4500)
# Root -> Left -> Left -> Left -> Left -> Leaf (prediction: -1.2074)
# Root -> Left -> Left -> Left -> Right -> Leaf (prediction: -1.2074)
# Root -> Left -> Left -> Right -> Leaf (prediction: -1.1130)
# Root -> Left -> Right -> Split on feature 7 (threshold: 0.9932)
# Root -> Left -> Right -> Left -> Leaf (prediction: -1.0127)
# Root -> Left -> Right -> Right -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.9868)
# Root -> Left -> Right -> Right -> Right -> Split on feature 9 (threshold: 0.4550)
# Root -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: -0.9449)
# Root -> Left -> Right -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.7825)
# Root -> Left -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: -0.9348)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.9348)
# Root -> Right -> Split on feature 4 (threshold: 0.0675)
# Root -> Right -> Left -> Split on feature 9 (threshold: 0.7850)
# Root -> Right -> Left -> Left -> Split on feature 8 (threshold: 3.6250)
# Root -> Right -> Left -> Left -> Left -> Split on feature 6 (threshold: 72.5000)
# Root -> Right -> Left -> Left -> Left -> Left -> Split on feature 8 (threshold: 3.2350)
# Root -> Right -> Left -> Left -> Left -> Left -> Left -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Left -> Left -> Left -> Right -> Leaf (prediction: -1.1665)
# Root -> Right -> Left -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0185)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Leaf (prediction: -1.1937)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 0 (threshold: 5.0500)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: -1.1955)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Split on feature 6 (threshold: 242.5000)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Split on feature 8 (threshold: 2.8950)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -1.1965)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Right -> Split on feature 0 (threshold: 7.0500)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: -1.1944)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Split on feature 8 (threshold: 3.2950)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Left -> Split on feature 0 (threshold: 6.8500)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: -1.1801)
# Root -> Right -> Left -> Left -> Right -> Leaf (prediction: -1.1684)
# Root -> Right -> Left -> Right -> Split on feature 6 (threshold: 113.5000)
# Root -> Right -> Left -> Right -> Left -> Leaf (prediction: -1.1036)
# Root -> Right -> Left -> Right -> Right -> Split on feature 0 (threshold: 7.0500)
# Root -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -1.2074)
# Root -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: -1.1937)
# Root -> Right -> Right -> Split on feature 1 (threshold: 0.4025)
# Root -> Right -> Right -> Left -> Split on feature 6 (threshold: 90.5000)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.9932)
# Root -> Right -> Right -> Left -> Right -> Split on feature 0 (threshold: 7.2500)
# Root -> Right -> Right -> Left -> Right -> Left -> Split on feature 5 (threshold: 23.5000)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: -1.1814)
# Root -> Right -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: -1.2074)
# Root -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -1.1165)
# Root -> Right -> Right -> Right -> Split on feature 6 (threshold: 147.5000)
# Root -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.1350)
# Root -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -1.0030)
# Root -> Right -> Right -> Right -> Left -> Right -> Split on feature 7 (threshold: 0.9961)
# Root -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.9485)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.9348)
# Root -> Right -> Right -> Right -> Right -> Leaf (prediction: -1.1392)
#
# Tree 2:
# Root -> Split on feature 6 (threshold: 65.5000)
# Root -> Left -> Split on feature 7 (threshold: 0.9932)
# Root -> Left -> Left -> Split on feature 2 (threshold: 0.1650)
# Root -> Left -> Left -> Left -> Leaf (prediction: 0.1104)
# Root -> Left -> Left -> Right -> Split on feature 1 (threshold: 0.2675)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0658)
# Root -> Left -> Left -> Right -> Right -> Leaf (prediction: -0.0516)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.4350)
# Root -> Left -> Right -> Left -> Leaf (prediction: 0.0866)
# Root -> Left -> Right -> Right -> Split on feature 7 (threshold: 0.9937)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1362)
# Root -> Left -> Right -> Right -> Right -> Split on feature 6 (threshold: 54.5000)
# Root -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1777)
# Root -> Left -> Right -> Right -> Right -> Right -> Split on feature 7 (threshold: 0.9961)
# Root -> Left -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1457)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1773)
# Root -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Right -> Left -> Split on feature 6 (threshold: 80.5000)
# Root -> Right -> Left -> Left -> Split on feature 7 (threshold: 0.9950)
# Root -> Right -> Left -> Left -> Left -> Split on feature 9 (threshold: 0.6250)
# Root -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0652)
# Root -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0389)
# Root -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.1799)
# Root -> Right -> Left -> Right -> Split on feature 0 (threshold: 8.4500)
# Root -> Right -> Left -> Right -> Left -> Split on feature 9 (threshold: 0.8250)
# Root -> Right -> Left -> Right -> Left -> Left -> Split on feature 1 (threshold: 0.3625)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Split on feature 6 (threshold: 238.2500)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Split on feature 8 (threshold: 2.8950)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0524)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Right -> Split on feature 6 (threshold: 102.5000)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Right -> Left -> Split on feature 7 (threshold: 0.9953)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0641)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0369)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Right -> Right -> Leaf (prediction: -0.0650)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0511)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Split on feature 9 (threshold: 0.6650)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Split on feature 9 (threshold: 0.4950)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0650)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 3.8250)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0336)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Right -> Right -> Split on feature 10 (threshold: 11.0250)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0650)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0509)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: 0.0161)
# Root -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0129)
# Root -> Right -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.3675)
# Root -> Right -> Left -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.1650)
# Root -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0650)
# Root -> Right -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0237)
# Root -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1004)
# Root -> Right -> Right -> Split on feature 7 (threshold: 0.9955)
# Root -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.3450)
# Root -> Right -> Right -> Left -> Left -> Split on feature 6 (threshold: 110.5000)
# Root -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0510)
# Root -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0655)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0468)
# Root -> Right -> Right -> Right -> Split on feature 3 (threshold: 8.2250)
# Root -> Right -> Right -> Right -> Left -> Split on feature 6 (threshold: 133.5000)
# Root -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.1789)
# Root -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.1406)
# Root -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0429)
#
# Tree 3:
# Root -> Split on feature 4 (threshold: 0.0615)
# Root -> Left -> Split on feature 6 (threshold: 49.5000)
# Root -> Left -> Left -> Split on feature 4 (threshold: 0.0385)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0298)
# Root -> Left -> Left -> Right -> Split on feature 6 (threshold: 28.5000)
# Root -> Left -> Left -> Right -> Left -> Split on feature 8 (threshold: 3.2850)
# Root -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1501)
# Root -> Left -> Left -> Right -> Left -> Right -> Split on feature 4 (threshold: 0.0555)
# Root -> Left -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1663)
# Root -> Left -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1595)
# Root -> Left -> Left -> Right -> Right -> Leaf (prediction: 0.0957)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.7150)
# Root -> Left -> Right -> Left -> Split on feature 1 (threshold: 0.5625)
# Root -> Left -> Right -> Left -> Left -> Split on feature 2 (threshold: 0.0950)
# Root -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0405)
# Root -> Left -> Right -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0185)
# Root -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0497)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Split on feature 0 (threshold: 5.0500)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0512)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Split on feature 6 (threshold: 242.5000)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 2.8950)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0527)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 64.5000)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0557)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0641)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0512)
# Root -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 3.9250)
# Root -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0016)
# Root -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0647)
# Root -> Left -> Right -> Right -> Split on feature 6 (threshold: 89.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0523)
# Root -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.3075)
# Root -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: -0.0643)
# Root -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0435)
# Root -> Right -> Split on feature 6 (threshold: 113.5000)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9933)
# Root -> Right -> Left -> Left -> Leaf (prediction: -0.0021)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 6.9500)
# Root -> Right -> Left -> Right -> Left -> Split on feature 7 (threshold: 0.9938)
# Root -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1308)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 1 (threshold: 0.2675)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1430)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Split on feature 6 (threshold: 100.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Split on feature 3 (threshold: 1.5250)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.1518)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 66.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Left -> Split on feature 9 (threshold: 0.4650)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1610)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: 0.1567)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1656)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1581)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1656)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0707)
# Root -> Right -> Right -> Split on feature 0 (threshold: 7.7500)
# Root -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.4175)
# Root -> Right -> Right -> Left -> Left -> Split on feature 7 (threshold: 0.9931)
# Root -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0495)
# Root -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0642)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0110)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.1391)
#
# Tree 4:
# Root -> Split on feature 4 (threshold: 0.0615)
# Root -> Left -> Split on feature 6 (threshold: 49.5000)
# Root -> Left -> Left -> Split on feature 4 (threshold: 0.0385)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0288)
# Root -> Left -> Left -> Right -> Split on feature 9 (threshold: 0.5050)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0776)
# Root -> Left -> Left -> Right -> Right -> Split on feature 11 (threshold: 5.5000)
# Root -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1292)
# Root -> Left -> Left -> Right -> Right -> Right -> Split on feature 4 (threshold: 0.0545)
# Root -> Left -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1495)
# Root -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1437)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.7850)
# Root -> Left -> Right -> Left -> Split on feature 8 (threshold: 3.6250)
# Root -> Left -> Right -> Left -> Left -> Split on feature 4 (threshold: 0.0595)
# Root -> Left -> Right -> Left -> Left -> Left -> Split on feature 6 (threshold: 64.5000)
# Root -> Left -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0419)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0185)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0500)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 6 (threshold: 242.5000)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Split on feature 0 (threshold: 5.0500)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0507)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Split on feature 2 (threshold: 0.0650)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0505)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Split on feature 8 (threshold: 2.8950)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0516)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0632)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0501)
# Root -> Left -> Right -> Left -> Left -> Right -> Split on feature 8 (threshold: 3.2450)
# Root -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0633)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: 0.0060)
# Root -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0145)
# Root -> Left -> Right -> Right -> Split on feature 6 (threshold: 106.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0339)
# Root -> Left -> Right -> Right -> Right -> Split on feature 0 (threshold: 7.0500)
# Root -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: -0.0640)
# Root -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0488)
# Root -> Right -> Split on feature 6 (threshold: 113.5000)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9934)
# Root -> Right -> Left -> Left -> Leaf (prediction: 0.0099)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 6.9500)
# Root -> Right -> Left -> Right -> Left -> Split on feature 1 (threshold: 0.2675)
# Root -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1295)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 1.5250)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1303)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Split on feature 6 (threshold: 81.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Split on feature 9 (threshold: 0.4550)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.1458)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 66.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1413)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1433)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.4925)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1579)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1419)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0651)
# Root -> Right -> Right -> Split on feature 0 (threshold: 7.7500)
# Root -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.3825)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0633)
# Root -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 158.5000)
# Root -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0725)
# Root -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0648)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.1250)
#
# Tree 5:
# Root -> Split on feature 4 (threshold: 0.0615)
# Root -> Left -> Split on feature 6 (threshold: 49.5000)
# Root -> Left -> Left -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Left -> Left -> Leaf (prediction: 0.0027)
# Root -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0987)
# Root -> Left -> Left -> Right -> Right -> Split on feature 9 (threshold: 0.5850)
# Root -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1366)
# Root -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1309)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.7150)
# Root -> Left -> Right -> Left -> Split on feature 1 (threshold: 0.5625)
# Root -> Left -> Right -> Left -> Left -> Split on feature 2 (threshold: 0.0950)
# Root -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0381)
# Root -> Left -> Right -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0185)
# Root -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0475)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Split on feature 6 (threshold: 242.5000)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Split on feature 0 (threshold: 5.0500)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0491)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Right -> Split on feature 8 (threshold: 2.8950)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0505)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Split on feature 6 (threshold: 64.5000)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0537)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0624)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0490)
# Root -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 3.9250)
# Root -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0038)
# Root -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0630)
# Root -> Left -> Right -> Right -> Split on feature 6 (threshold: 89.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0486)
# Root -> Left -> Right -> Right -> Right -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.3950)
# Root -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0629)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0486)
# Root -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0324)
# Root -> Right -> Split on feature 6 (threshold: 113.5000)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9929)
# Root -> Right -> Left -> Left -> Leaf (prediction: -0.0201)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 6.9500)
# Root -> Right -> Left -> Right -> Left -> Split on feature 7 (threshold: 0.9936)
# Root -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.0896)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 5.4250)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Split on feature 3 (threshold: 1.6250)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Left -> Split on feature 9 (threshold: 0.5750)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.1115)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.1318)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Split on feature 5 (threshold: 34.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Split on feature 6 (threshold: 66.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1294)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1353)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1299)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1359)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1132)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0602)
# Root -> Right -> Right -> Split on feature 0 (threshold: 7.7500)
# Root -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.3825)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0625)
# Root -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 158.5000)
# Root -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0666)
# Root -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0638)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.1138)
#
# Tree 6:
# Root -> Split on feature 6 (threshold: 70.5000)
# Root -> Left -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Left -> Split on feature 7 (threshold: 0.9934)
# Root -> Left -> Left -> Left -> Split on feature 5 (threshold: 17.5000)
# Root -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0636)
# Root -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0486)
# Root -> Left -> Left -> Right -> Leaf (prediction: 0.0369)
# Root -> Left -> Right -> Split on feature 1 (threshold: 0.2275)
# Root -> Left -> Right -> Left -> Leaf (prediction: 0.0834)
# Root -> Left -> Right -> Right -> Split on feature 4 (threshold: 0.0515)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0925)
# Root -> Left -> Right -> Right -> Right -> Split on feature 10 (threshold: 12.7750)
# Root -> Left -> Right -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.2725)
# Root -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.1083)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 66.5000)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Split on feature 7 (threshold: 0.9939)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.1301)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: 0.1202)
# Root -> Left -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.1142)
# Root -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1437)
# Root -> Right -> Split on feature 4 (threshold: 0.0675)
# Root -> Right -> Left -> Split on feature 2 (threshold: 0.1150)
# Root -> Right -> Left -> Left -> Split on feature 6 (threshold: 103.5000)
# Root -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.0466)
# Root -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0625)
# Root -> Right -> Left -> Right -> Split on feature 0 (threshold: 5.1500)
# Root -> Right -> Left -> Right -> Left -> Split on feature 8 (threshold: 3.4450)
# Root -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0624)
# Root -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0160)
# Root -> Right -> Left -> Right -> Right -> Split on feature 4 (threshold: 0.0205)
# Root -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0406)
# Root -> Right -> Left -> Right -> Right -> Right -> Split on feature 6 (threshold: 77.2500)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Split on feature 7 (threshold: 0.9928)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0621)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0175)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Split on feature 8 (threshold: 2.9450)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Split on feature 3 (threshold: 2.2250)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0339)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0619)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Split on feature 2 (threshold: 0.2350)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.3150)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0617)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Right -> Split on feature 4 (threshold: 0.0435)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0620)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0329)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0617)
# Root -> Right -> Right -> Split on feature 6 (threshold: 153.5000)
# Root -> Right -> Right -> Left -> Split on feature 7 (threshold: 0.9948)
# Root -> Right -> Right -> Left -> Left -> Split on feature 4 (threshold: 0.0905)
# Root -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0251)
# Root -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0649)
# Root -> Right -> Right -> Left -> Right -> Split on feature 8 (threshold: 3.1250)
# Root -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0330)
# Root -> Right -> Right -> Left -> Right -> Right -> Split on feature 8 (threshold: 3.1850)
# Root -> Right -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1033)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.4175)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1398)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Split on feature 6 (threshold: 113.5000)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1207)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1324)
# Root -> Right -> Right -> Right -> Leaf (prediction: -0.0631)
#
# Tree 7:
# Root -> Split on feature 6 (threshold: 70.5000)
# Root -> Left -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Left -> Split on feature 9 (threshold: 0.5550)
# Root -> Left -> Left -> Left -> Split on feature 0 (threshold: 7.6500)
# Root -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0631)
# Root -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0502)
# Root -> Left -> Left -> Right -> Leaf (prediction: 0.0364)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.4350)
# Root -> Left -> Right -> Left -> Leaf (prediction: 0.0567)
# Root -> Left -> Right -> Right -> Split on feature 9 (threshold: 0.4650)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0932)
# Root -> Left -> Right -> Right -> Right -> Split on feature 7 (threshold: 0.9935)
# Root -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1264)
# Root -> Left -> Right -> Right -> Right -> Right -> Split on feature 11 (threshold: 4.5000)
# Root -> Left -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1074)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Split on feature 4 (threshold: 0.0545)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1194)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.2675)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1156)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Right -> Split on feature 3 (threshold: 5.1250)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1120)
# Root -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1162)
# Root -> Right -> Split on feature 4 (threshold: 0.0675)
# Root -> Right -> Left -> Split on feature 9 (threshold: 0.7850)
# Root -> Right -> Left -> Left -> Split on feature 8 (threshold: 3.6250)
# Root -> Right -> Left -> Left -> Left -> Split on feature 4 (threshold: 0.0195)
# Root -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0333)
# Root -> Right -> Left -> Left -> Left -> Right -> Split on feature 6 (threshold: 91.5000)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Split on feature 8 (threshold: 3.3850)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Left -> Split on feature 5 (threshold: 33.5000)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0612)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0454)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0231)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 8 (threshold: 2.8950)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0466)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0609)
# Root -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0211)
# Root -> Right -> Left -> Right -> Split on feature 1 (threshold: 0.2875)
# Root -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0546)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0362)
# Root -> Right -> Right -> Split on feature 9 (threshold: 0.5050)
# Root -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.4925)
# Root -> Right -> Right -> Left -> Left -> Split on feature 9 (threshold: 0.4750)
# Root -> Right -> Right -> Left -> Left -> Left -> Split on feature 6 (threshold: 121.5000)
# Root -> Right -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0665)
# Root -> Right -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0614)
# Root -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0356)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0479)
# Root -> Right -> Right -> Right -> Split on feature 6 (threshold: 154.5000)
# Root -> Right -> Right -> Right -> Left -> Split on feature 7 (threshold: 0.9956)
# Root -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.0151)
# Root -> Right -> Right -> Right -> Left -> Right -> Split on feature 0 (threshold: 7.2500)
# Root -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.1020)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Split on feature 5 (threshold: 32.5000)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Left -> Split on feature 9 (threshold: 0.7050)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Left -> Left -> Split on feature 6 (threshold: 108.5000)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.1132)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.1171)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.1192)
# Root -> Right -> Right -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1286)
# Root -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0632)
#
# Tree 8:
# Root -> Split on feature 4 (threshold: 0.0615)
# Root -> Left -> Split on feature 6 (threshold: 54.5000)
# Root -> Left -> Left -> Split on feature 4 (threshold: 0.0375)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0519)
# Root -> Left -> Left -> Right -> Split on feature 9 (threshold: 0.4850)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0453)
# Root -> Left -> Left -> Right -> Right -> Split on feature 8 (threshold: 3.2350)
# Root -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1012)
# Root -> Left -> Left -> Right -> Right -> Right -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1245)
# Root -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1078)
# Root -> Left -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Left -> Right -> Left -> Split on feature 10 (threshold: 13.4500)
# Root -> Left -> Right -> Left -> Left -> Split on feature 9 (threshold: 0.7850)
# Root -> Left -> Right -> Left -> Left -> Left -> Split on feature 4 (threshold: 0.0195)
# Root -> Left -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0345)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Split on feature 8 (threshold: 2.8950)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0476)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 6 (threshold: 72.5000)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Split on feature 10 (threshold: 11.6167)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0619)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0327)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Split on feature 2 (threshold: 0.2350)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.3150)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0603)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Split on feature 4 (threshold: 0.0435)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0608)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0298)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0603)
# Root -> Left -> Right -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0621)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: -0.0014)
# Root -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0118)
# Root -> Left -> Right -> Right -> Split on feature 6 (threshold: 106.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0452)
# Root -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0611)
# Root -> Right -> Split on feature 6 (threshold: 128.5000)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9933)
# Root -> Right -> Left -> Left -> Leaf (prediction: -0.0102)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 8.7250)
# Root -> Right -> Left -> Right -> Left -> Split on feature 6 (threshold: 99.5000)
# Root -> Right -> Left -> Right -> Left -> Left -> Split on feature 7 (threshold: 0.9949)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Split on feature 8 (threshold: 3.2550)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: 0.0736)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: 0.1079)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Split on feature 6 (threshold: 81.5000)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.1056)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.5975)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1120)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1072)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 7 (threshold: 0.9961)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0076)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Split on feature 5 (threshold: 21.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1019)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.1180)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0144)
# Root -> Right -> Right -> Split on feature 6 (threshold: 153.5000)
# Root -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.3675)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0610)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0766)
# Root -> Right -> Right -> Right -> Leaf (prediction: -0.0614)
#
# Tree 9:
# Root -> Split on feature 4 (threshold: 0.0615)
# Root -> Left -> Split on feature 6 (threshold: 54.5000)
# Root -> Left -> Left -> Split on feature 4 (threshold: 0.0375)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0509)
# Root -> Left -> Left -> Right -> Split on feature 9 (threshold: 0.4850)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0426)
# Root -> Left -> Left -> Right -> Right -> Split on feature 3 (threshold: 2.2250)
# Root -> Left -> Left -> Right -> Right -> Left -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.1151)
# Root -> Left -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.1021)
# Root -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0958)
# Root -> Left -> Right -> Split on feature 1 (threshold: 0.4875)
# Root -> Left -> Right -> Left -> Split on feature 10 (threshold: 13.4500)
# Root -> Left -> Right -> Left -> Left -> Split on feature 9 (threshold: 0.7850)
# Root -> Left -> Right -> Left -> Left -> Left -> Split on feature 4 (threshold: 0.0195)
# Root -> Left -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0335)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Split on feature 6 (threshold: 72.5000)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Left -> Split on feature 10 (threshold: 11.6167)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0611)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0317)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 3 (threshold: 0.9250)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0491)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Split on feature 2 (threshold: 0.2350)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.1950)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0425)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Split on feature 6 (threshold: 92.5000)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0422)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0598)
# Root -> Left -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: -0.0597)
# Root -> Left -> Right -> Left -> Left -> Right -> Split on feature 4 (threshold: 0.0465)
# Root -> Left -> Right -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0614)
# Root -> Left -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: -0.0013)
# Root -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0113)
# Root -> Left -> Right -> Right -> Split on feature 6 (threshold: 106.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0420)
# Root -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0605)
# Root -> Right -> Split on feature 6 (threshold: 128.5000)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9934)
# Root -> Right -> Left -> Left -> Split on feature 6 (threshold: 75.5000)
# Root -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.0753)
# Root -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0637)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 8.7250)
# Root -> Right -> Left -> Right -> Left -> Split on feature 9 (threshold: 0.4550)
# Root -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.0631)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 1 (threshold: 0.2575)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0803)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Split on feature 3 (threshold: 1.5250)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0930)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.3075)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.0954)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Split on feature 6 (threshold: 91.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Split on feature 5 (threshold: 26.5000)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Left -> Leaf (prediction: 0.1013)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.1135)
# Root -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0136)
# Root -> Right -> Right -> Split on feature 0 (threshold: 7.7500)
# Root -> Right -> Right -> Left -> Split on feature 5 (threshold: 24.5000)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0318)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: -0.0605)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.0706)
#
# Tree 10:
# Root -> Split on feature 4 (threshold: 0.0585)
# Root -> Left -> Split on feature 6 (threshold: 49.5000)
# Root -> Left -> Left -> Split on feature 9 (threshold: 0.4150)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0471)
# Root -> Left -> Left -> Right -> Split on feature 8 (threshold: 3.2150)
# Root -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0456)
# Root -> Left -> Left -> Right -> Right -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.1139)
# Root -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0980)
# Root -> Left -> Right -> Split on feature 9 (threshold: 0.7850)
# ...
# Root -> Right -> Right -> Left -> Split on feature 0 (threshold: 9.0500)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0512)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0489)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.0642)
#
# Tree 98:
# Root -> Split on feature 4 (threshold: 0.0485)
# Root -> Left -> Split on feature 8 (threshold: 3.2350)
# Root -> Left -> Left -> Split on feature 0 (threshold: 10.2500)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0504)
# Root -> Left -> Left -> Right -> Leaf (prediction: 0.0186)
# Root -> Left -> Right -> Split on feature 6 (threshold: 101.5000)
# Root -> Left -> Right -> Left -> Split on feature 3 (threshold: 1.5250)
# Root -> Left -> Right -> Left -> Left -> Split on feature 8 (threshold: 3.7550)
# Root -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0526)
# Root -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.0540)
# Root -> Left -> Right -> Left -> Right -> Split on feature 4 (threshold: 0.0375)
# Root -> Left -> Right -> Left -> Right -> Left -> Split on feature 6 (threshold: 99.5000)
# Root -> Left -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0506)
# Root -> Left -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: 0.0334)
# Root -> Left -> Right -> Left -> Right -> Right -> Split on feature 9 (threshold: 0.6450)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0207)
# Root -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0532)
# Root -> Left -> Right -> Right -> Split on feature 5 (threshold: 56.5000)
# Root -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0503)
# Root -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0120)
# Root -> Right -> Split on feature 3 (threshold: 8.6250)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9946)
# Root -> Right -> Left -> Left -> Split on feature 11 (threshold: 5.5000)
# Root -> Right -> Left -> Left -> Left -> Split on feature 6 (threshold: 47.5000)
# Root -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: 0.0524)
# Root -> Right -> Left -> Left -> Left -> Right -> Split on feature 0 (threshold: 5.8500)
# Root -> Right -> Left -> Left -> Left -> Right -> Left -> Leaf (prediction: -0.0054)
# Root -> Right -> Left -> Left -> Left -> Right -> Right -> Leaf (prediction: -0.0539)
# Root -> Right -> Left -> Left -> Right -> Split on feature 1 (threshold: 0.2875)
# Root -> Right -> Left -> Left -> Right -> Left -> Split on feature 8 (threshold: 2.9250)
# Root -> Right -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.0851)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Split on feature 6 (threshold: 39.5000)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0509)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: -0.0497)
# Root -> Right -> Left -> Left -> Right -> Right -> Split on feature 7 (threshold: 0.9922)
# Root -> Right -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: 0.0028)
# Root -> Right -> Left -> Left -> Right -> Right -> Right -> Split on feature 2 (threshold: 0.4850)
# Root -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Split on feature 8 (threshold: 3.2750)
# Root -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.0237)
# Root -> Right -> Left -> Left -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0521)
# Root -> Right -> Left -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.0763)
# Root -> Right -> Left -> Right -> Split on feature 6 (threshold: 148.5000)
# Root -> Right -> Left -> Right -> Left -> Split on feature 1 (threshold: 0.2375)
# Root -> Right -> Left -> Right -> Left -> Left -> Split on feature 6 (threshold: 66.5000)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.0508)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0175)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 1.5250)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0172)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Split on feature 5 (threshold: 48.7500)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Split on feature 9 (threshold: 0.5150)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: 0.0409)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0527)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0141)
# Root -> Right -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.7825)
# Root -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0506)
# Root -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0404)
# Root -> Right -> Right -> Split on feature 2 (threshold: 0.7700)
# Root -> Right -> Right -> Left -> Split on feature 0 (threshold: 9.0500)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0511)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0486)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.0633)
#
# Tree 99:
# Root -> Split on feature 4 (threshold: 0.0485)
# Root -> Left -> Split on feature 8 (threshold: 3.2350)
# Root -> Left -> Left -> Split on feature 0 (threshold: 10.2500)
# Root -> Left -> Left -> Left -> Leaf (prediction: -0.0504)
# Root -> Left -> Left -> Right -> Leaf (prediction: 0.0178)
# Root -> Left -> Right -> Split on feature 3 (threshold: 4.3250)
# Root -> Left -> Right -> Left -> Split on feature 3 (threshold: 1.5250)
# Root -> Left -> Right -> Left -> Left -> Split on feature 8 (threshold: 3.8150)
# Root -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0517)
# Root -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.0587)
# Root -> Left -> Right -> Left -> Right -> Split on feature 7 (threshold: 0.9902)
# Root -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0509)
# Root -> Left -> Right -> Left -> Right -> Right -> Split on feature 7 (threshold: 0.9934)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Split on feature 10 (threshold: 11.6167)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0503)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Split on feature 10 (threshold: 12.8467)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0176)
# Root -> Left -> Right -> Left -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0579)
# Root -> Left -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0470)
# Root -> Left -> Right -> Right -> Leaf (prediction: -0.0504)
# Root -> Right -> Split on feature 3 (threshold: 8.6250)
# Root -> Right -> Left -> Split on feature 7 (threshold: 0.9946)
# Root -> Right -> Left -> Left -> Split on feature 10 (threshold: 11.4583)
# Root -> Right -> Left -> Left -> Left -> Split on feature 1 (threshold: 0.5350)
# Root -> Right -> Left -> Left -> Left -> Left -> Split on feature 10 (threshold: 11.1500)
# Root -> Right -> Left -> Left -> Left -> Left -> Left -> Split on feature 7 (threshold: 0.9944)
# Root -> Right -> Left -> Left -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0528)
# Root -> Right -> Left -> Left -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0162)
# Root -> Right -> Left -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0222)
# Root -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: 0.0186)
# Root -> Right -> Left -> Left -> Right -> Split on feature 5 (threshold: 35.2500)
# Root -> Right -> Left -> Left -> Right -> Left -> Split on feature 7 (threshold: 0.9916)
# Root -> Right -> Left -> Left -> Right -> Left -> Left -> Leaf (prediction: -0.0240)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Split on feature 1 (threshold: 0.3825)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Left -> Split on feature 3 (threshold: 2.2250)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Left -> Left -> Leaf (prediction: 0.0338)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Left -> Right -> Leaf (prediction: -0.0046)
# Root -> Right -> Left -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0565)
# Root -> Right -> Left -> Left -> Right -> Right -> Leaf (prediction: 0.0779)
# Root -> Right -> Left -> Right -> Split on feature 3 (threshold: 4.4250)
# Root -> Right -> Left -> Right -> Left -> Split on feature 3 (threshold: 1.5250)
# Root -> Right -> Left -> Right -> Left -> Left -> Split on feature 5 (threshold: 16.5000)
# Root -> Right -> Left -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.0523)
# Root -> Right -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0298)
# Root -> Right -> Left -> Right -> Left -> Right -> Split on feature 8 (threshold: 3.5850)
# Root -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0497)
# Root -> Right -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0215)
# Root -> Right -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.3825)
# Root -> Right -> Left -> Right -> Right -> Left -> Split on feature 10 (threshold: 10.5583)
# Root -> Right -> Left -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0513)
# Root -> Right -> Left -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0070)
# Root -> Right -> Left -> Right -> Right -> Right -> Split on feature 10 (threshold: 11.0250)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Split on feature 7 (threshold: 0.9974)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0186)
# Root -> Right -> Left -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0401)
# Root -> Right -> Left -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.0632)
# Root -> Right -> Right -> Split on feature 2 (threshold: 0.7700)
# Root -> Right -> Right -> Left -> Split on feature 0 (threshold: 9.0500)
# Root -> Right -> Right -> Left -> Left -> Leaf (prediction: -0.0509)
# Root -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0483)
# Root -> Right -> Right -> Right -> Leaf (prediction: 0.0625)
#
# Tree 100:
# Root -> Split on feature 6 (threshold: 53.5000)
# Root -> Left -> Split on feature 4 (threshold: 0.0525)
# Root -> Left -> Left -> Split on feature 8 (threshold: 3.3850)
# Root -> Left -> Left -> Left -> Split on feature 9 (threshold: 0.5050)
# Root -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0480)
# Root -> Left -> Left -> Left -> Right -> Leaf (prediction: 0.0017)
# Root -> Left -> Left -> Right -> Leaf (prediction: 0.0453)
# Root -> Left -> Right -> Leaf (prediction: 0.0506)
# Root -> Right -> Split on feature 4 (threshold: 0.0445)
# Root -> Right -> Left -> Split on feature 4 (threshold: 0.0125)
# Root -> Right -> Left -> Left -> Leaf (prediction: 0.0323)
# Root -> Right -> Left -> Right -> Split on feature 8 (threshold: 3.4550)
# Root -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0503)
# Root -> Right -> Left -> Right -> Right -> Split on feature 4 (threshold: 0.0385)
# Root -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0511)
# Root -> Right -> Left -> Right -> Right -> Right -> Leaf (prediction: 0.0263)
# Root -> Right -> Right -> Split on feature 6 (threshold: 149.5000)
# Root -> Right -> Right -> Left -> Split on feature 9 (threshold: 0.4350)
# Root -> Right -> Right -> Left -> Left -> Split on feature 6 (threshold: 73.5000)
# Root -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: 0.0134)
# Root -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0508)
# Root -> Right -> Right -> Left -> Right -> Split on feature 5 (threshold: 18.5000)
# Root -> Right -> Right -> Left -> Right -> Left -> Split on feature 1 (threshold: 0.5250)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Split on feature 8 (threshold: 3.3150)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Left -> Split on feature 10 (threshold: 9.5167)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: -0.0247)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Left -> Right -> Leaf (prediction: -0.0534)
# Root -> Right -> Right -> Left -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.0137)
# Root -> Right -> Right -> Left -> Right -> Left -> Right -> Split on feature 3 (threshold: 1.9250)
# Root -> Right -> Right -> Left -> Right -> Left -> Right -> Left -> Leaf (prediction: 0.0061)
# Root -> Right -> Right -> Left -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0501)
# Root -> Right -> Right -> Left -> Right -> Right -> Split on feature 1 (threshold: 0.1725)
# Root -> Right -> Right -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0513)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Split on feature 1 (threshold: 0.3825)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Split on feature 3 (threshold: 2.8250)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Split on feature 9 (threshold: 0.6950)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Split on feature 9 (threshold: 0.4450)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Left -> Leaf (prediction: 0.0574)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Right -> Split on feature 6 (threshold: 75.5000)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Right -> Left -> Leaf (prediction: 0.0429)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Right -> Right -> Split on feature 5 (threshold: 38.2500)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Right -> Right -> Left -> Leaf (prediction: -0.0507)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Left -> Right -> Right -> Right -> Leaf (prediction: -0.0087)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.0544)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Right -> Split on feature 2 (threshold: 0.7700)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Right -> Left -> Leaf (prediction: -0.0504)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Left -> Right -> Right -> Leaf (prediction: 0.0617)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Split on feature 10 (threshold: 11.2500)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Split on feature 1 (threshold: 0.4525)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Left -> Split on feature 4 (threshold: 0.0755)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0158)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: 0.0353)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0521)
# Root -> Right -> Right -> Left -> Right -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.0623)
# Root -> Right -> Right -> Right -> Split on feature 10 (threshold: 12.2250)
# Root -> Right -> Right -> Right -> Left -> Split on feature 0 (threshold: 9.7500)
# Root -> Right -> Right -> Right -> Left -> Left -> Split on feature 0 (threshold: 8.0500)
# Root -> Right -> Right -> Right -> Left -> Left -> Left -> Leaf (prediction: -0.0506)
# Root -> Right -> Right -> Right -> Left -> Left -> Right -> Leaf (prediction: -0.0232)
# Root -> Right -> Right -> Right -> Left -> Right -> Leaf (prediction: 0.0317)
# Root -> Right -> Right -> Right -> Right -> Leaf (prediction: 0.0853)

# %%
sample = win_date.loc[0,]
pred_path = get_prediction_path(model, sample)
print("\nPrediction path for a single sample:")
for step in pred_path:
    print(step)
# Out:
# Prediction path for a single sample:
# Feature 6 <= 65.5000
# Feature 4 > 0.0465
# Feature 7 > 0.9932
# Feature 4 > 0.0525
# Feature 9 > 0.4550
# Feature 1 <= 0.7825
# Leaf (prediction: -0.9348)
# Feature 6 <= 65.5000
# Feature 7 > 0.9932
# Feature 9 > 0.4350
# Feature 7 > 0.9937
# Feature 6 <= 54.5000
# Leaf (prediction: 0.1777)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9933
# Feature 3 <= 6.9500
# Feature 7 > 0.9938
# Feature 1 > 0.2675
# Feature 6 <= 100.5000
# Feature 3 > 1.5250
# Feature 6 <= 66.5000
# Feature 9 > 0.4650
# Leaf (prediction: 0.1567)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9934
# Feature 3 <= 6.9500
# Feature 1 > 0.2675
# Feature 3 > 1.5250
# Feature 6 <= 81.5000
# Feature 9 > 0.4550
# Feature 6 <= 66.5000
# Leaf (prediction: 0.1413)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9929
# Feature 3 <= 6.9500
# Feature 7 > 0.9936
# Feature 3 <= 5.4250
# Feature 3 > 1.6250
# Feature 5 <= 34.5000
# Feature 6 <= 66.5000
# Leaf (prediction: 0.1294)
# Feature 6 <= 70.5000
# Feature 4 > 0.0465
# Feature 1 > 0.2275
# Feature 4 > 0.0515
# Feature 10 <= 12.7750
# Feature 1 > 0.2725
# Feature 6 <= 66.5000
# Feature 7 > 0.9939
# Leaf (prediction: 0.1202)
# Feature 6 <= 70.5000
# Feature 4 > 0.0465
# Feature 9 > 0.4350
# Feature 9 > 0.4650
# Feature 7 > 0.9935
# Feature 11 > 4.5000
# Feature 4 > 0.0545
# Feature 1 > 0.2675
# Feature 3 <= 5.1250
# Leaf (prediction: 0.1120)
# Feature 4 > 0.0615
# Feature 6 <= 128.5000
# Feature 7 > 0.9933
# Feature 3 <= 8.7250
# Feature 6 <= 99.5000
# Feature 7 > 0.9949
# Feature 6 <= 81.5000
# Leaf (prediction: 0.1056)
# Feature 4 > 0.0615
# Feature 6 <= 128.5000
# Feature 7 > 0.9934
# Feature 3 <= 8.7250
# Feature 9 > 0.4550
# Feature 1 > 0.2575
# Feature 3 > 1.5250
# Feature 1 > 0.3075
# Feature 6 <= 91.5000
# Leaf (prediction: 0.1000)
# Feature 4 > 0.0585
# Feature 6 <= 96.5000
# Feature 7 > 0.9928
# Feature 6 <= 90.5000
# Feature 8 > 3.1050
# Feature 7 > 0.9938
# Feature 1 > 0.3075
# Leaf (prediction: 0.0955)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9929
# Feature 6 <= 89.5000
# Feature 2 <= 0.6550
# Feature 7 > 0.9938
# Feature 3 <= 5.4250
# Feature 9 > 0.4550
# Feature 1 > 0.2425
# Leaf (prediction: 0.0911)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9929
# Feature 6 <= 89.5000
# Feature 2 <= 0.6550
# Feature 7 > 0.9938
# Feature 3 <= 5.4250
# Leaf (prediction: 0.0878)
# Feature 4 > 0.0615
# Feature 6 <= 113.5000
# Feature 7 > 0.9929
# Feature 6 <= 89.5000
# Feature 3 > 1.5250
# Feature 7 > 0.9938
# Feature 3 <= 5.7500
# Feature 9 > 0.4550
# Feature 1 > 0.2425
# Leaf (prediction: 0.0843)
# Feature 4 > 0.0575
# Feature 6 <= 103.5000
# Feature 7 > 0.9928
# Feature 6 <= 89.5000
# Feature 6 <= 73.5000
# Feature 7 > 0.9937
# Feature 4 > 0.0605
# Feature 9 > 0.4450
# Feature 1 > 0.2875
# Leaf (prediction: 0.0816)
# Feature 4 > 0.0575
# Feature 6 <= 103.5000
# Feature 7 > 0.9928
# Feature 6 <= 89.5000
# Feature 3 > 1.5250
# Feature 7 > 0.9938
# Feature 1 > 0.3075
# Leaf (prediction: 0.0793)
# Feature 4 > 0.0615
# Feature 6 <= 149.5000
# Feature 9 > 0.4750
# Feature 7 > 0.9923
# Feature 1 > 0.2575
# Feature 3 > 1.5250
# Feature 10 <= 12.4500
# Feature 7 > 0.9946
# Feature 6 <= 94.5000
# Feature 9 > 0.4950
# Leaf (prediction: 0.0771)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9928
# Feature 3 > 1.5250
# Feature 7 > 0.9938
# Feature 5 <= 35.2500
# Feature 1 > 0.3075
# Feature 4 > 0.0625
# Leaf (prediction: 0.0750)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9928
# Feature 3 > 1.5250
# Feature 7 > 0.9938
# Feature 5 <= 35.2500
# Leaf (prediction: 0.0733)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9928
# Feature 3 > 1.5250
# Feature 7 > 0.9938
# Feature 5 <= 35.2500
# Feature 1 > 0.3075
# Leaf (prediction: 0.0715)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 1 > 0.2275
# Feature 6 <= 68.5000
# Feature 10 <= 12.6500
# Feature 3 > 1.4750
# Feature 9 > 0.4550
# Leaf (prediction: 0.0702)
# Feature 4 > 0.0585
# Feature 6 <= 149.5000
# Feature 9 > 0.4750
# Feature 7 > 0.9919
# Feature 1 > 0.2375
# Feature 8 > 3.1150
# Feature 1 > 0.2725
# Feature 6 <= 120.5000
# Feature 10 <= 11.7750
# Feature 7 > 0.9946
# Feature 6 <= 100.5000
# Feature 3 <= 5.8250
# Leaf (prediction: 0.0683)
# Feature 4 > 0.0585
# Feature 6 <= 149.5000
# Feature 9 > 0.4750
# Feature 7 > 0.9919
# Feature 1 > 0.2375
# Feature 8 > 3.1150
# Feature 1 > 0.2725
# Feature 6 <= 120.5000
# Feature 10 <= 11.7750
# Feature 7 > 0.9946
# Feature 6 <= 100.5000
# Feature 3 <= 5.8250
# Leaf (prediction: 0.0671)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9936
# Feature 9 > 0.4550
# Feature 1 > 0.3075
# Leaf (prediction: 0.0664)
# Feature 4 > 0.0585
# Feature 3 <= 6.1500
# Feature 7 > 0.9944
# Feature 7 > 0.9952
# Feature 4 > 0.0625
# Leaf (prediction: 0.0656)
# Feature 4 > 0.0585
# Feature 3 <= 6.1500
# Feature 7 > 0.9944
# Feature 3 <= 4.6250
# Feature 7 > 0.9952
# Feature 4 > 0.0625
# Leaf (prediction: 0.0648)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 6 <= 86.5000
# Feature 1 > 0.2275
# Feature 6 <= 68.5000
# Feature 10 <= 12.6500
# Leaf (prediction: 0.0637)
# Feature 6 <= 70.5000
# Feature 7 > 0.9925
# Feature 9 > 0.4150
# Feature 3 <= 4.8250
# Feature 11 > 4.5000
# Feature 10 <= 12.3167
# Leaf (prediction: 0.0633)
# Feature 6 <= 70.5000
# Feature 7 > 0.9925
# Feature 9 > 0.3950
# Feature 3 <= 4.8250
# Feature 3 > 1.4750
# Feature 7 > 0.9936
# Leaf (prediction: 0.0625)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 6 <= 86.5000
# Feature 7 > 0.9937
# Feature 6 <= 80.5000
# Feature 9 > 0.4550
# Feature 6 <= 71.5000
# Leaf (prediction: 0.0612)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 7 > 0.9937
# Feature 6 <= 90.5000
# Feature 11 > 4.5000
# Feature 6 <= 71.5000
# Feature 9 > 0.4650
# Leaf (prediction: 0.0606)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9936
# Feature 9 > 0.4550
# Feature 4 > 0.0615
# Leaf (prediction: 0.0601)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9936
# Feature 9 > 0.4550
# Feature 4 > 0.0615
# Feature 1 > 0.2425
# Leaf (prediction: 0.0594)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9936
# Feature 9 > 0.4550
# Feature 4 > 0.0615
# Leaf (prediction: 0.0589)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9929
# Feature 7 > 0.9944
# Feature 11 > 4.5000
# Leaf (prediction: 0.0586)
# Feature 4 > 0.0585
# Feature 6 <= 89.5000
# Feature 7 > 0.9928
# Feature 3 > 1.6250
# Feature 3 <= 5.9250
# Feature 4 > 0.0625
# Leaf (prediction: 0.0581)
# Feature 4 > 0.0565
# Feature 6 <= 113.5000
# Feature 1 > 0.2725
# Feature 8 > 3.1450
# Feature 0 > 5.9500
# Feature 6 <= 99.5000
# Leaf (prediction: 0.0578)
# Feature 4 > 0.0565
# Feature 6 <= 113.5000
# Feature 1 > 0.2725
# Feature 8 > 3.1450
# Feature 0 > 5.9500
# Feature 6 <= 99.5000
# Leaf (prediction: 0.0574)
# Feature 4 > 0.0565
# Feature 6 <= 113.5000
# Feature 1 > 0.2725
# Feature 6 <= 68.5000
# Feature 7 > 0.9937
# Leaf (prediction: 0.0568)
# Feature 4 > 0.0565
# Feature 6 <= 113.5000
# Feature 7 > 0.9932
# Feature 6 <= 89.5000
# Feature 8 > 3.1350
# Feature 5 <= 38.2500
# Leaf (prediction: 0.0565)
# Feature 4 > 0.0565
# Feature 6 <= 113.5000
# Feature 1 > 0.2725
# Feature 6 <= 68.5000
# Feature 7 > 0.9936
# Leaf (prediction: 0.0561)
# Feature 6 <= 72.5000
# Feature 4 > 0.0465
# Feature 1 > 0.2725
# Feature 4 > 0.0515
# Feature 10 <= 12.8467
# Feature 4 <= 0.1400
# Feature 4 > 0.0635
# Leaf (prediction: 0.0558)
# Feature 6 <= 72.5000
# Feature 4 > 0.0465
# Feature 9 > 0.4650
# Feature 11 > 4.5000
# Feature 1 > 0.2675
# Feature 7 > 0.9934
# Feature 4 > 0.0605
# Leaf (prediction: 0.0553)
# Feature 4 > 0.0575
# Feature 9 > 0.4750
# Feature 3 <= 9.0500
# Feature 7 > 0.9950
# Feature 3 <= 4.4250
# Leaf (prediction: 0.0553)
# Feature 4 > 0.0575
# Feature 9 > 0.4750
# Feature 3 <= 9.0500
# Feature 7 > 0.9919
# Feature 7 > 0.9950
# Feature 3 <= 5.6500
# Leaf (prediction: 0.0546)
# Feature 6 <= 72.5000
# Feature 4 > 0.0465
# Feature 9 > 0.4650
# Feature 11 > 4.5000
# Feature 1 > 0.2675
# Feature 7 > 0.9932
# Feature 4 > 0.0605
# Leaf (prediction: 0.0545)
# Feature 4 > 0.0575
# Feature 6 <= 86.5000
# Feature 7 > 0.9928
# Feature 7 > 0.9944
# Feature 4 > 0.0605
# Leaf (prediction: 0.0544)
# Feature 4 > 0.0575
# Feature 6 <= 86.5000
# Feature 7 > 0.9928
# Feature 7 > 0.9944
# Feature 4 > 0.0605
# Leaf (prediction: 0.0542)
# Feature 4 > 0.0575
# Feature 6 <= 86.5000
# Feature 7 > 0.9928
# Feature 7 > 0.9944
# Feature 4 > 0.0605
# Leaf (prediction: 0.0540)
# Feature 4 > 0.0575
# Feature 6 <= 86.5000
# Feature 3 > 1.4750
# Feature 1 > 0.2725
# Feature 6 <= 75.5000
# Feature 10 <= 12.8467
# Feature 4 > 0.0605
# Leaf (prediction: 0.0538)
# Feature 4 > 0.0565
# Feature 6 <= 86.5000
# Feature 7 > 0.9928
# Feature 8 > 3.1050
# Feature 4 > 0.0605
# Leaf (prediction: 0.0537)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 7 > 0.9944
# Feature 3 <= 9.2250
# Feature 1 > 0.2375
# Feature 9 > 0.4650
# Feature 3 > 1.4750
# Feature 6 <= 144.5000
# Feature 3 <= 6.3250
# Leaf (prediction: 0.0540)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 9 > 0.4750
# Feature 3 > 1.5250
# Feature 1 > 0.2375
# Feature 6 <= 146.5000
# Feature 3 <= 8.0500
# Feature 10 <= 12.7750
# Feature 3 > 1.6250
# Feature 1 > 0.3125
# Feature 6 <= 93.5000
# Leaf (prediction: 0.0531)
# Feature 6 <= 92.5000
# Feature 7 > 0.9932
# Feature 8 > 3.1050
# Feature 3 <= 5.1250
# Feature 4 > 0.0455
# Feature 10 <= 10.8500
# Feature 7 > 0.9948
# Leaf (prediction: 0.0533)
# Feature 4 > 0.0585
# Feature 6 <= 155.5000
# Feature 7 > 0.9944
# Feature 1 > 0.2675
# Feature 9 > 0.4750
# Feature 5 <= 43.5000
# Feature 9 > 0.4850
# Feature 6 <= 143.5000
# Feature 6 <= 93.5000
# Leaf (prediction: 0.0528)
# Feature 6 <= 92.5000
# Feature 7 > 0.9932
# Feature 9 > 0.4550
# Feature 3 <= 4.8250
# Feature 2 <= 0.6750
# Feature 4 > 0.0455
# Feature 9 > 0.4950
# Feature 4 > 0.0575
# Leaf (prediction: 0.0528)
# Feature 4 > 0.0625
# Feature 6 <= 53.5000
# Feature 7 > 0.9935
# Leaf (prediction: 0.0526)
# Feature 4 > 0.0625
# Feature 6 <= 53.5000
# Leaf (prediction: 0.0531)
# Feature 6 <= 67.5000
# Feature 7 > 0.9944
# Feature 3 <= 6.2500
# Feature 11 > 4.5000
# Leaf (prediction: 0.0531)
# Feature 4 > 0.0625
# Feature 6 <= 53.5000
# Feature 7 > 0.9933
# Leaf (prediction: 0.0523)
# Feature 6 <= 67.5000
# Feature 7 > 0.9944
# Feature 3 <= 6.3250
# Feature 11 > 4.5000
# Leaf (prediction: 0.0528)
# Feature 6 <= 68.5000
# Feature 4 > 0.0525
# Feature 1 > 0.2675
# Feature 7 > 0.9931
# Leaf (prediction: 0.0522)
# Feature 6 <= 68.5000
# Feature 4 > 0.0525
# Feature 1 > 0.2675
# Feature 7 > 0.9931
# Leaf (prediction: 0.0521)
# Feature 6 <= 68.5000
# Feature 4 > 0.0525
# Feature 1 > 0.2675
# Leaf (prediction: 0.0525)
# Feature 6 <= 68.5000
# Feature 4 > 0.0525
# Feature 1 > 0.2675
# Leaf (prediction: 0.0524)
# Feature 6 <= 68.5000
# Feature 4 > 0.0525
# Feature 1 > 0.2675
# Leaf (prediction: 0.0523)
# Feature 6 <= 54.5000
# Feature 9 > 0.4150
# Feature 4 > 0.0375
# Feature 4 > 0.0395
# Feature 4 > 0.0475
# Leaf (prediction: 0.0521)
# Feature 4 > 0.0625
# Feature 7 > 0.9944
# Feature 3 <= 9.6250
# Feature 3 <= 4.8250
# Feature 3 > 1.5250
# Feature 7 > 0.9948
# Leaf (prediction: 0.0516)
# Feature 6 <= 54.5000
# Feature 9 > 0.4150
# Feature 4 > 0.0375
# Feature 7 > 0.9925
# Feature 4 > 0.0425
# Leaf (prediction: 0.0517)
# Feature 6 <= 54.5000
# Feature 9 > 0.4150
# Feature 4 > 0.0375
# Feature 7 > 0.9925
# Feature 4 > 0.0425
# Leaf (prediction: 0.0516)
# Feature 6 <= 67.5000
# Feature 4 > 0.0515
# Feature 1 > 0.2675
# Feature 7 > 0.9931
# Leaf (prediction: 0.0514)
# Feature 6 <= 67.5000
# Feature 7 > 0.9915
# Feature 1 > 0.2725
# Feature 4 > 0.0475
# Feature 7 > 0.9929
# Feature 6 <= 64.5000
# Feature 4 > 0.0545
# Leaf (prediction: 0.0513)
# Feature 6 <= 67.5000
# Feature 9 > 0.4650
# Feature 7 > 0.9915
# Feature 1 > 0.2075
# Feature 8 > 3.0250
# Feature 4 > 0.0395
# Feature 6 <= 64.5000
# Feature 7 > 0.9936
# Leaf (prediction: 0.0514)
# Feature 6 <= 66.5000
# Feature 9 > 0.4650
# Feature 4 > 0.0375
# Feature 1 > 0.1950
# Feature 6 <= 64.5000
# Feature 4 > 0.0395
# Feature 3 <= 4.9500
# Leaf (prediction: 0.0516)
# Feature 6 <= 66.5000
# Feature 9 > 0.4650
# Feature 7 > 0.9915
# Feature 1 > 0.2075
# Feature 8 > 3.0250
# Feature 6 <= 64.5000
# Feature 7 > 0.9922
# Leaf (prediction: 0.0518)
# Feature 6 <= 67.5000
# Feature 9 > 0.4650
# Feature 1 > 0.2075
# Feature 7 > 0.9915
# Feature 8 > 3.0250
# Feature 6 <= 64.5000
# Feature 7 > 0.9922
# Leaf (prediction: 0.0517)
# Feature 4 > 0.0485
# Feature 6 <= 91.5000
# Feature 7 > 0.9915
# Feature 9 > 0.4750
# Feature 4 > 0.0515
# Feature 1 > 0.2375
# Feature 11 > 4.5000
# Leaf (prediction: 0.0518)
# Feature 4 > 0.0485
# Feature 6 <= 91.5000
# Feature 1 > 0.2725
# Feature 8 > 3.1450
# Feature 6 <= 88.5000
# Feature 6 <= 78.5000
# Leaf (prediction: 0.0511)
# Feature 4 > 0.0485
# Feature 6 <= 91.5000
# Feature 7 > 0.9915
# Feature 9 > 0.4750
# Feature 4 > 0.0515
# Feature 3 > 1.5250
# Feature 6 <= 84.5000
# Feature 6 <= 76.5000
# Leaf (prediction: 0.0510)
# Feature 4 > 0.0485
# Feature 6 <= 91.5000
# Feature 7 > 0.9915
# Feature 9 > 0.4750
# Feature 1 > 0.2575
# Feature 4 > 0.0525
# Feature 11 > 4.5000
# Leaf (prediction: 0.0511)
# Feature 4 > 0.0485
# Feature 6 <= 91.5000
# Feature 7 > 0.9915
# Feature 9 > 0.4950
# Feature 3 > 1.5250
# Feature 4 > 0.0525
# Feature 6 <= 87.5000
# Leaf (prediction: 0.0513)
# Feature 6 <= 92.5000
# Feature 7 > 0.9944
# Feature 3 <= 9.0500
# Feature 11 > 4.5000
# Feature 1 > 0.2375
# Feature 3 <= 8.2250
# Feature 1 > 0.2675
# Feature 4 > 0.0435
# Leaf (prediction: 0.0508)
# Feature 6 <= 92.5000
# Feature 7 > 0.9944
# Feature 3 <= 9.0500
# Feature 4 > 0.0485
# Feature 1 > 0.2375
# Feature 4 > 0.0525
# Leaf (prediction: 0.0509)
# Feature 6 <= 53.5000
# Feature 9 > 0.3650
# Feature 3 <= 4.8250
# Feature 7 > 0.9926
# Leaf (prediction: 0.0516)
# Feature 6 <= 53.5000
# Feature 4 > 0.0525
# Feature 7 > 0.9929
# Leaf (prediction: 0.0508)
# Feature 6 <= 92.5000
# Feature 7 > 0.9944
# Feature 3 <= 3.1250
# Feature 4 > 0.0525
# Leaf (prediction: 0.0508)
# Feature 4 > 0.0485
# Feature 6 <= 68.5000
# Feature 1 > 0.2275
# Feature 4 > 0.0515
# Leaf (prediction: 0.0510)
# Feature 4 > 0.0485
# Feature 6 <= 68.5000
# Feature 1 > 0.2275
# Feature 4 > 0.0515
# Leaf (prediction: 0.0510)
# Feature 4 > 0.0485
# Feature 6 <= 68.5000
# Feature 7 > 0.9915
# Feature 4 > 0.0515
# Feature 1 > 0.1875
# Leaf (prediction: 0.0509)
# Feature 6 <= 68.5000
# Feature 7 > 0.9944
# Feature 3 <= 3.1250
# Leaf (prediction: 0.0511)
# Feature 4 > 0.0485
# Feature 6 <= 68.5000
# Feature 7 > 0.9915
# Feature 4 > 0.0515
# Feature 1 > 0.1875
# Leaf (prediction: 0.0508)
# Feature 6 <= 102.5000
# Feature 7 > 0.9944
# Feature 3 <= 3.1250
# Feature 4 > 0.0405
# Leaf (prediction: 0.0507)
# Feature 6 <= 102.5000
# Feature 7 > 0.9944
# Feature 4 > 0.0495
# Feature 6 <= 81.5000
# Leaf (prediction: 0.0506)
# Feature 6 <= 102.5000
# Feature 7 > 0.9944
# Feature 3 <= 3.1250
# Leaf (prediction: 0.0510)
# Feature 6 <= 53.5000
# Feature 4 > 0.0335
# Feature 4 > 0.0525
# Leaf (prediction: 0.0507)
# Feature 6 <= 53.5000
# Feature 9 > 0.4150
# Feature 4 > 0.0335
# Feature 7 > 0.9925
# Leaf (prediction: 0.0511)
# Feature 6 <= 53.5000
# Feature 9 > 0.3950
# Feature 8 > 3.0050
# Feature 7 > 0.9924
# Leaf (prediction: 0.0510)
# Feature 4 > 0.0485
# Feature 3 <= 8.6250
# Feature 7 > 0.9946
# Feature 6 <= 148.5000
# Feature 1 > 0.2375
# Feature 3 > 1.5250
# Feature 5 <= 48.7500
# Feature 3 <= 8.2250
# Leaf (prediction: 0.0502)
# Feature 4 > 0.0485
# Feature 3 <= 8.6250
# Feature 7 > 0.9946
# Feature 6 <= 148.5000
# Feature 1 > 0.2375
# Feature 3 > 1.5250
# Feature 5 <= 48.7500
# Feature 9 > 0.5150
# Leaf (prediction: 0.0527)
# Feature 4 > 0.0485
# Feature 3 <= 8.6250
# Feature 7 > 0.9946
# Feature 3 <= 4.4250
# Feature 3 > 1.5250
# Feature 8 <= 3.5850
# Leaf (prediction: 0.0497)
# Feature 6 <= 53.5000
# Feature 4 > 0.0525
# Leaf (prediction: 0.0506)
# C:\Users\admin\AppData\Local\Temp\ipykernel_61540\200308572.py:19: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if sample[feature] <= threshold:
