# %%
from ollama import chat

stream = chat(
    model='deepseek-r1',
    messages=[{'role': 'user', 'content': 'Why is the sky blue?'}],
    stream=True,
)

for chunk in stream:
  print(chunk['message']['content'], end='', flush=True)
# Out:
# <think>
# Okay, so I'm trying to figure out why the sky appears blue. I remember when I was a kid, my dad used to tell me it's because of something with light and the atmosphere. But now that I think about it more deeply, maybe there's more to it than just that.
#
# First off, white light is made up of all the colors of the rainbow, right? So if you break down white light into its component colors, you get red, orange, yellow, green, blue, indigo, and violet. I think this happens through something called dispersion, where light bends and separates into these different colors. But how does that relate to the sky being blue?
#
# Maybe it has something to do with how our atmosphere interacts with white light. I remember reading somewhere about Rayleigh scattering. From what I understand, when sunlight enters the Earth's atmosphere, the tiny particles in the air—like molecules of nitrogen and oxygen—scatter the different colors of light differently based on their wavelengths.
#
# So shorter wavelengths, like blue and violet, are scattered more than longer ones like red. That makes sense because blue has a shorter wavelength compared to red. But wait, why is the sky specifically blue then? If violet is even shorter than blue, shouldn't it be scattered more?
#
# Hmm, maybe I'm missing something here. Maybe our eyes have less sensitivity to violet light compared to blue. Or perhaps the sun's output isn't perfectly white; maybe it emits more blue and less violet at noon when the sky is truly blue. Also, in some circumstances like during sunrise or sunset, the sky turns red because the light has to pass through a longer path of the atmosphere, scattering the blue out, leaving the orange and red.
#
# But then why don't we see violet in the sky? Maybe it's because our eyes aren't as sensitive to violet. I think when we look at things that are violet or purples, they seem bright and vivid, but maybe our brains process it differently than how much light is actually being scattered.
#
# Also, during the day, when the sun is high in the sky, the atmosphere scatters more of the blue wavelengths, so the sky appears blue. At sunset, as the sun sets lower, the light
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2f/gylrw_qs6xj4j6hygjj1_wgc0000gn/T/ipykernel_61726/3233436926.py in <module>
#       7 )
#       8
# ----> 9 for chunk in stream:
#      10   print(chunk['message']['content'], end='', flush=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ollama/_client.py in inner()
#     168             raise ResponseError(e.response.text, e.response.status_code) from None
#     169
# --> 170           for line in r.iter_lines():
#     171             part = json.loads(line)
#     172             if err := part.get('error'):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in iter_lines(self)
#     859         decoder = LineDecoder()
#     860         with request_context(request=self._request):
# --> 861             for text in self.iter_text():
#     862                 for line in decoder.decode(text):
#     863                     yield line
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in iter_text(self, chunk_size)
#     846         chunker = TextChunker(chunk_size=chunk_size)
#     847         with request_context(request=self._request):
# --> 848             for byte_content in self.iter_bytes():
#     849                 text_content = decoder.decode(byte_content)
#     850                 for chunk in chunker.decode(text_content):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in iter_bytes(self, chunk_size)
#     827             chunker = ByteChunker(chunk_size=chunk_size)
#     828             with request_context(request=self._request):
# --> 829                 for raw_bytes in self.iter_raw():
#     830                     decoded = decoder.decode(raw_bytes)
#     831                     for chunk in chunker.decode(decoded):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in iter_raw(self, chunk_size)
#     881
#     882         with request_context(request=self._request):
# --> 883             for raw_stream_bytes in self.stream:
#     884                 self._num_bytes_downloaded += len(raw_stream_bytes)
#     885                 for chunk in chunker.decode(raw_stream_bytes):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_client.py in __iter__(self)
#     124
#     125     def __iter__(self) -> typing.Iterator[bytes]:
# --> 126         for chunk in self._stream:
#     127             yield chunk
#     128
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_transports/default.py in __iter__(self)
#     111     def __iter__(self) -> typing.Iterator[bytes]:
#     112         with map_httpcore_exceptions():
# --> 113             for part in self._httpcore_stream:
#     114                 yield part
#     115
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     365         except BaseException as exc:
#     366             self.close()
# --> 367             raise exc from None
#     368
#     369     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     361     def __iter__(self) -> Iterator[bytes]:
#     362         try:
# --> 363             for part in self._stream:
#     364                 yield part
#     365         except BaseException as exc:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/http11.py in __iter__(self)
#     347             with ShieldCancellation():
#     348                 self.close()
# --> 349             raise exc
#     350
#     351     def close(self) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/http11.py in __iter__(self)
#     339         try:
#     340             with Trace("receive_response_body", logger, self._request, kwargs):
# --> 341                 for chunk in self._connection._receive_response_body(**kwargs):
#     342                     yield chunk
#     343         except BaseException as exc:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/http11.py in _receive_response_body(self, request)
#     208
#     209         while True:
# --> 210             event = self._receive_event(timeout=timeout)
#     211             if isinstance(event, h11.Data):
#     212                 yield bytes(event.data)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     222
#     223             if event is h11.NEED_DATA:
# --> 224                 data = self._network_stream.read(
#     225                     self.READ_NUM_BYTES, timeout=timeout
#     226                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     124         with map_exceptions(exc_map):
#     125             self._sock.settimeout(timeout)
# --> 126             return self._sock.recv(max_bytes)
#     127
#     128     def write(self, buffer: bytes, timeout: typing.Optional[float] = None) -> None:
#
# KeyboardInterrupt:
